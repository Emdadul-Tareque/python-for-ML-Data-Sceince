# %% [markdown]
# # matplotlib.pyplot.scatter()
#
# [Scatterplot and Correlation important video](https://youtu.be/wqMwTDVT9_Y?si=bFLoVLWzfS2L3aRd)

# %% [markdown]
# One basic way of creating a scatterplot is through Matplotlib's scatter function:

# %% [markdown]
# ## Example 1 a. Scatter plot showing negative correlation between two variables

# %%
# Import Neccessary libray 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# Read CSV file
fuel_econ = pd.read_csv('./fuel-econ.csv')

fuel_econ.head(10)
# Out:
#       id        make           model  year  ...     comb  co2 feScore ghgScore
# 0  32204      Nissan            GT-R  2013  ...  18.7389  471       4        4
# 1  32205  Volkswagen              CC  2013  ...  25.2227  349       6        6
# 2  32206  Volkswagen              CC  2013  ...  20.6716  429       5        5
# 3  32207  Volkswagen      CC 4motion  2013  ...  19.8774  446       5        5
# 4  32208   Chevrolet  Malibu eAssist  2013  ...  28.6813  310       8        8
# 5  32209       Lexus          GS 350  2013  ...  22.6002  393       6        6
# 6  32210       Lexus      GS 350 AWD  2013  ...  21.4213  412       5        5
# 7  32214     Hyundai   Genesis Coupe  2013  ...  20.6507  432       5        5
# 8  32215     Hyundai   Genesis Coupe  2013  ...  23.8235  375       6        6
# 9  32216     Hyundai   Genesis Coupe  2013  ...  19.3344  461       4        4
#
# [10 rows x 20 columns]

# %%
fuel_econ[['displ', 'comb']]
# Out:
#       displ     comb
# 0       3.8  18.7389
# 1       2.0  25.2227
# 2       3.6  20.6716
# 3       3.6  19.8774
# 4       2.4  28.6813
# ...     ...      ...
# 3924    1.8  54.4329
# 3925    2.0  41.0000
# 3926    2.0  42.0000
# 3927    3.4  23.0021
# 3928    3.4  21.3945
#
# [3929 rows x 2 columns]

# %%
# Scatter plot
plt.scatter(data= fuel_econ, x='displ', y='comb')
plt.xlabel('Displaement (1)')
plt.ylabel('Combined Fuel Eff. (mpg)')
# Out:
# Text(0, 0.5, 'Combined Fuel Eff. (mpg)')

# %% [markdown]
# In the example above, the relationship between the two variables is negative because as higher values of the x-axis variable are increasing, the values of the variable plotted on the y-axis are decreasing

# %% [markdown]
# # Alternative Approach - seaborn.regplot()

# %% [markdown]
# Seaborn's regplot() function combines scatterplot creation with regression function fitting:

# %% [markdown]
# ## Example 1 b. Scatter plot showing negative correlation between two variables

# %%
sb.regplot(data= fuel_econ, x='displ', y='comb')
plt.xlabel('Displacement(1)')
plt.ylabel('Combined Fuel Eff. (mpg)')
# Out:
# Text(0, 0.5, 'Combined Fuel Eff. (mpg)')

# %% [markdown]
# The regression line in a scatter plot showing a negative correlation between the two variables

# %% [markdown]
# ## Example 3. Plot the regression line on the transformed data

# %%
def log_trans(x, inverse = False):
    if not inverse:
        return np.log10(x)
    else:
        return np.power(10, x)

sb.regplot(data= fuel_econ, x=fuel_econ['displ'], y=fuel_econ['comb'].apply(log_trans))
tick_locs = [10, 20, 50, 100]
plt.yticks(log_trans(tick_locs), tick_locs);
