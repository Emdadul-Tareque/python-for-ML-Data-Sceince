# %%
class Student:
    def __init__(self, name, id):
        self.name = name
        self.__id = id
     # প্রোপার্টি ডেকোরেটর ব্যবহার করার মাধ্যেম আমরা student id ম্যাথডকে
    # প্রোপার্টি হিসেবে ব্যবহার করতে পারব।  
    @property
    def student_id(self):
        return self.__id

# %%
student1 = Student("emdadul", 101)

# %%
student1.student_id #Read only
# Out:
# 101

# %%
student1.student_id = 102 # এখানে আমরা কিন্তু সেই প্রপার্টির ভ্যালু সেট করতে পারব না
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-6f7c108c0cf9> in <module>
# ----> 1 student1.student_id = 102 # এখানে আমরা কিন্তু সেই প্রপার্টির ভ্যালু সেট করতে পারব না
#
# AttributeError: can't set attribute

# %%
class Student:
    def __init__(self, name, id):
        self._name = name
        self.__id = id
        
    @property    
    def name(self):
        return self._name
    @property
    def student_id(self):
        return self.__id
    @name.deleter
    def name(self):
        del self._name

# %%
student1 = Student("emdadul", 101)

# %%
del student1.name

# %%
student1.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-de12cdc9bd3f> in <module>
# ----> 1 student1.name
#
# <ipython-input-17-82b17113aa6a> in name(self)
#       6     @property
#       7     def name(self):
# ----> 8         return self._name
#       9     @property
#      10     def student_id(self):
#
# AttributeError: 'Student' object has no attribute '_name'

# %%
class Course:
    
    def __init__(self, course_name, course_price):
        self.course_name = course_name
        self.__course_price = course_price
        
        
    @property
    def course_price_access(self):
        return self.__course_price
    
    @course_price_access.setter
    def course_price_set(self, price):
        self.__course_price = price
        
    @course_price_access.deleter
    def delete_course_price(self):
        del self.__course_price

# %%
course = Course("Python course", "6500")

# %%
course.course_price_access
# Out:
# '6500'

# %%
course.course_price_set = 7500

# %%
del course.delete_course_price

# %%
course.course_price_access
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-68daf3e3d273> in <module>
# ----> 1 course.course_price_access
#
# <ipython-input-13-ded3ba762c46> in course_price_access(self)
#       8     @property
#       9     def course_price_access(self):
# ---> 10         return self.__course_price
#      11
#      12     @course_price_access.setter
#
# AttributeError: 'Course' object has no attribute '_Course__course_price'
